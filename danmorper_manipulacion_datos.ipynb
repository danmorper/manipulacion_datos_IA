# %%
import numpy as np
import pandas as pd
import siuba as sb

flights = pd.read_csv('data/flights.csv')

# para ver los primeros 10 registros
print(flights.head(10))
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
# 5  2013      1    1     554.0             558       -4.0     740.0
# 6  2013      1    1     555.0             600       -5.0     913.0
# 7  2013      1    1     557.0             600       -3.0     709.0
# 8  2013      1    1     557.0             600       -3.0     838.0
# 9  2013      1    1     558.0             600       -2.0     753.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# ...

# %%
flights[flights['arr_delay'] >= 120]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 119     2013      1    1     811.0             630      101.0    1047.0
# 151     2013      1    1     848.0            1835      853.0    1001.0
# 218     2013      1    1     957.0             733      144.0    1056.0
# 268     2013      1    1    1114.0             900      134.0    1447.0
# 447     2013      1    1    1505.0            1310      115.0    1638.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336579  2013      9   30    1823.0            1545      158.0    1934.0
# 336668  2013      9   30    1951.0            1649      182.0    2157.0
# 336724  2013      9   30    2053.0            1815      158.0    2310.0
# 336757  2013      9   30    2159.0            1845      194.0    2344.0
# 336763  2013      9   30    2235.0            2001      154.0      59.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
sb.filter(flights,flights.month==1, flights.day==1)
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1     517.0             515        2.0     830.0
# 1    2013      1    1     533.0             529        4.0     850.0
# 2    2013      1    1     542.0             540        2.0     923.0
# 3    2013      1    1     544.0             545       -1.0    1004.0
# 4    2013      1    1     554.0             600       -6.0     812.0
# ..    ...    ...  ...       ...             ...        ...       ...
# 837  2013      1    1    2356.0            2359       -3.0     425.0
# 838  2013      1    1       NaN            1630        NaN       NaN
# 839  2013      1    1       NaN            1935        NaN       NaN
# 840  2013      1    1       NaN            1500        NaN       NaN
# 841  2013      1    1       NaN             600        NaN       NaN
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# ...

# %% [markdown]
# Es muy raro porque si hago como en los apuntes me da error

# %%
flights[flights['dest'].isin(['IAH', 'HOU'])]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 32      2013      1    1     623.0             627       -4.0     933.0
# 81      2013      1    1     728.0             732       -4.0    1041.0
# 89      2013      1    1     739.0             739        0.0    1104.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336524  2013      9   30    1729.0            1720        9.0    2001.0
# 336527  2013      9   30    1735.0            1715       20.0    2010.0
# 336618  2013      9   30    1859.0            1859        0.0    2134.0
# 336694  2013      9   30    2015.0            2015        0.0    2244.0
# 336737  2013      9   30    2105.0            2106       -1.0    2329.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
flights >> sb.filter((_.dep_delay <= 0) | (_.arr_delay <= 0)) #Da erorr una cosa de los apuntes
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# /var/folders/vh/zcb0v6590hq0668t1p4zhgqc0000gn/T/ipykernel_3323/3859460088.py in <module>
# ----> 1 flights >> sb.filter((_.dep_delay <= 0) | (_.arr_delay <= 0))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/siuba/siu/calls.py in __rrshift__(self, x)
#     212             raise TypeError()
#     213
# --> 214         return self(x)
#     215
#     216     @staticmethod
#
# ~/opt/anaconda3/lib/python3.9/site-packages/siuba/siu/calls.py in __call__(self, x)
#     187             return operator.getitem(inst, *rest)
#     188         elif self.func == "__call__":
# --> 189             return getattr(inst, self.func)(*rest, **kwargs)
#     190
#     191         # in normal case, get method to call, and then call it
#
# ~/opt/anaconda3/lib/python3.9/functools.py in wrapper(*args, **kw)
# ...

# %%
flights_sort = flights.sort_values('distance')
flights_sort.head(10)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 275945  2013      7   27       NaN             106        NaN       NaN
# 3083    2013      1    4    1240.0            1200       40.0    1333.0
# 16328   2013      1   19    1617.0            1617        0.0    1722.0
# 112178  2013      2    1    2128.0            2129       -1.0    2216.0
# 19983   2013      1   23    2128.0            2129       -1.0    2221.0
# 11249   2013      1   13    2243.0            2129       74.0    2400.0
# 137872  2013      3    2    1926.0            1929       -3.0    2011.0
# 116412  2013      2    6    2125.0            2129       -4.0    2207.0
# 117352  2013      2    7    2145.0            2129       16.0    2234.0
# 13068   2013      1   15    2122.0            2130       -8.0    2207.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 275945             245        NaN      US    1632     NaN    EWR  LGA
# ...

# %% [markdown]
# Escogemos los 10 vuelos que recorrieron menor distancia usando siuba

# %%
sb.arrange(flights, flights.distance) # no sé solucionar el error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/vh/zcb0v6590hq0668t1p4zhgqc0000gn/T/ipykernel_3323/189606253.py in <module>
# ----> 1 sb.arrange(flights, flights.distance)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/siuba/siu/dispatchers.py in wrapper(*args, **kwargs)
#     165             return dispatch_func(NoArgs(), **strip_kwargs)
#     166
# --> 167         return dispatch_func(*strip_args, **strip_kwargs)
#     168
#     169     return wrapper
#
# ~/opt/anaconda3/lib/python3.9/functools.py in wrapper(*args, **kw)
#     886                             '1 positional argument')
#     887
# --> 888         return dispatch(args[0].__class__)(*args, **kw)
#     889
#     890     funcname = getattr(func, '__name__', 'singledispatch function')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/siuba/dply/verbs.py in arrange(__data, *args)
# ...

# %%
flights_sort = flights.sort_values('arr_delay', ascending=False)
flights_sort.head(5)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 7072    2013      1    9     641.0             900     1301.0    1242.0
# 235778  2013      6   15    1432.0            1935     1137.0    1607.0
# 8239    2013      1   10    1121.0            1635     1126.0    1239.0
# 327043  2013      9   20    1139.0            1845     1014.0    1457.0
# 270376  2013      7   22     845.0            1600     1005.0    1044.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 7072              1530     1272.0      HA      51  N384HA    JFK  HNL
# 235778            2120     1127.0      MQ    3535  N504MQ    JFK  CMH
# 8239              1810     1109.0      MQ    3695  N517MQ    EWR  ORD
# 327043            2210     1007.0      AA     177  N338AA    JFK  SFO
# 270376            1815      989.0      MQ    3075  N665MQ    JFK  CVG
#
#         air_time  distance  hour  minute             time_hour
# ...

# %%
flights['speed'] = flights['distance'] / flights['air_time'] * 60
flights_sort = flights.sort_values('speed', ascending=False)
flights_sorted.head(1)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 216447  2013      5   25    1709.0            1700        9.0    1923.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 216447            1937      -14.0      DL    1499  N666DN    LGA  ATL
#
#         air_time  distance  hour  minute             time_hour       speed
# 216447      65.0       762    17       0  2013-05-25T21:00:00Z  703.384615

# %%
flights_speed = sb.mutate(flights, speed = (flights.distance / flights.air_time) * 60)
flights_sorted = sb.arrange(flights_speed, sb.desc(flights_speed.speed))
flights_sorted.head(1)

print(fastest_flight)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/vh/zcb0v6590hq0668t1p4zhgqc0000gn/T/ipykernel_3323/142264737.py in <module>
#       1 flights_speed = sb.mutate(flights, speed = (flights.distance / flights.air_time) * 60)
# ----> 2 flights_sorted = sb.arrange(flights_speed, sb.desc(flights_speed.speed))
#       3 flights_sorted.head(1)
#       4
#       5 print(fastest_flight)
#
# AttributeError: module 'siuba' has no attribute 'desc'

# %%
flights[['dep_time', 'dep_delay', 'arr_time', 'arr_delay']]
flights.loc[:, ['dep_time', 'dep_delay', 'arr_time', 'arr_delay']]
flights.filter(['dep_time', 'dep_delay', 'arr_time', 'arr_delay'])

# %%
flights['dep_time_mins'] = (np.floor(flights['dep_time'] / 100) * 60) + (flights['dep_time'] % 100)
flights['sched_dep_time_mins'] = (np.floor(flights['sched_dep_time'] / 100) * 60) + (flights['sched_dep_time'] % 100)
flights_selected = flights.drop(['dep_time', 'sched_dep_time'], axis=1)

# %%
flights['date'] = pd.to_datetime(flights[['year', 'month', 'day']])
flights_grouped = flights.groupby('date').agg({'dep_time': ['min', 'max']})
flights_grouped.columns = ['first_dep_time', 'last_dep_time']
